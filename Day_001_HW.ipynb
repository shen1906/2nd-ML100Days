# %% [markdown]
# ## 作業1
# #### 我選擇的資料：[LANL Earthquake Prediction](https://www.kaggle.com/c/LANL-Earthquake-Prediction/data)
#
# ### 選擇的理由：
# #### 這組數據是由實驗室中典型的地震模型（三塊石板中間放置粒狀碎石）的實驗結果。他們利用從兩側給予壓力以及中間的石板給予切剪應力來模擬地震的效果，藉由這組數據可以讓人們更了解地震發生可能出現的前兆。若能由此發展出預測地震的方法將能減少天災所造成的生命以及金錢的損失。（對世界很有貢獻）
#
# ### 資料來源：
# #### 美國 Penstate University 的 Department of Geoscience 進行實驗，但我無從詳細得知其實驗方法。（科學實驗）
#
# ### 資料型態：
# #### 數值
#
# ### 如何評估：
# #### 這組資料提供地震模型模擬出的地震，再多次測量地震模型，嘗試是否能夠成功預測地震的發生。

# %% [markdown]
# ## 作業2
#
# ### 核心問題：
# #### 如何有效提升業績（淨利增加）？ 載一組客人的淨利應與其乘坐地與目標地的距離有關，首先要先釐清載客距離與淨利之關係。（此部分應可直接利用理論模型預測，例如：基本費用＋距離所增收費用-開車成本-車輛返回成本）接著利用現在載客狀況的分佈來了解載客時間地點與乘客需求（前往目的地的距離）的關係，試著是否能運用這樣的優勢來派遣車輛在指定時間指定地點排班）以有效的提升業績。
#
# ### 資料來源：
# #### 資料來自於現在運行的車輛載客的基本資料。（載客地點，載客時間，客人乘車距離）
#
# ### 資料型態：
# #### 數值
#
# ### 如何評估：
# #### 實行，計算業績成長率

# %% [markdown]
# ## 練習時間  (作業3)
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    mse = sum((y - yp)**2)/len(y)
    return mse

def mean_absolute_error(y, yp):
    mae = sum(abs(y - yp))/len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 222.776
# The Mean absolute error is 11.622
